# %% [markdown]
# ## matplotlib
#
# Biblioteca para criar plots 2D.
#
# Alguns links úteis:
#
# - https://matplotlib.org/
#
# - https://matplotlib.org/gallery/index.html
#
# - https://matplotlib.org/tutorials/index.html
#
# - https://matplotlib.org/api/pyplot_summary.html
#
# - https://matplotlib.org/faq/usage_faq.html

# %%
from matplotlib import pyplot as plt 
# %matplotlib inline
plt.plot([1,2,3,3,4,5])
plt.show()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

print(menMeans)
print(womenMeans)

# visualização "empilhada"
p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))
plt.show()
# Out:
# (20, 35, 30, 35, 27)
# (25, 32, 34, 20, 25)

# %% [markdown]
# ## seaborn
#
# Biblioteca de visualização de dados baseada no matplotlib, oferecendo uma interface um pouco mais alto nível.
#
# Alguns links úteis:
#
# - https://seaborn.pydata.org/
#
# - https://seaborn.pydata.org/examples/index.html#example-gallery
#
# - https://seaborn.pydata.org/tutorial.html#tutorial
#
# - https://seaborn.pydata.org/introduction.html#introduction
#
# - https://seaborn.pydata.org/api.html#api-ref

# %%
import numpy as np
import seaborn as sns
sns.set(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x, y, kind="hex", color="#4CB391")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
corr = np.array([1,0,1,0,1,0,1,0,1]).reshape(3,3)
sns.heatmap(data=corr, annot=True)

# %%
classe_a = np.random.normal(50, 10, size=20)
classe_b = np.random.normal(70, 10, size=20)

plt.hist(classe_a, bins=range(0,100,10), alpha=1.0)
plt.hist(classe_b, bins=range(0,100,10), alpha=0.5)
plt.show()

# %%
ax = sns.distplot(classe_a, bins=range(0,100,10), kde=False, norm_hist=False)
ax = sns.distplot(classe_b, bins=range(0,100,10), kde=False, norm_hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(classe_a, bins=range(0,100,10))
ax = sns.distplot(classe_b, bins=range(0,100,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import pandas as pd
classes = len(classe_a)*['A'] + len(classe_b)*['B']
notas = np.concatenate((classe_a, classe_b))

df = pd.DataFrame({'Notas': notas, 'Turma': classes})
# print(df)
sns.boxplot(x="Turma", y="Notas", data=df)

# %% [markdown]
# ### Visualizando atributos do conjunto Iris

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
import pandas as pd

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

# %%
df = pd.DataFrame(X, columns=iris.feature_names)
colors=np.array(50*['r']+50*['g']+50*['b'])
pd.plotting.scatter_matrix(df, alpha=1.0, figsize=(15,15), color=colors)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5f0da674d0>,
# ...
#       dtype=object)

# %%
df = sns.load_dataset('iris')
sns.pairplot(df, hue="species")

# %%
plt.scatter(df['petal_length'], df['petal_width'])

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].scatter(df['sepal_length'], df['petal_length'], c=colors)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].scatter(df['sepal_length'], df['sepal_width'], c=colors)
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].scatter(df['sepal_length'], df['petal_length'], c=colors)
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].scatter(df['sepal_length'], df['petal_width'], c=colors)
axs[1, 1].set_title('Axis [1, 1]')
# Out:
# Text(0.5, 1.0, 'Axis [1, 1]')

# %% [markdown]
# ### Pie chart

# %%
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
dist = [20, 20, 5, 5, 3, 7, 10, 20, 10]

plt.pie(dist, labels=letters)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5f0b11bf10>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'A'),
#   Text(-0.3399187231970732, 1.046162158377023, 'B'),
#   Text(-0.9801071964785992, 0.499389510713692, 'C'),
#   Text(-1.0864571823074214, 0.1720778632265596, 'D'),
#   Text(-1.0951181564353798, -0.1035191936095683, 'E'),
#   Text(-1.0095300692329319, -0.4368627236496062, 'F'),
#   Text(-0.6465637337786145, -0.8899187255936675, 'G'),
#   Text(0.33991875992786186, -1.0461621464424646, 'H'),
#   Text(1.0461621941806911, -0.33991861300470483, 'I')])

# %%
new_dist = [0]
letras = ['outros']

for l,v in zip(letters, dist):
  if v < 20:
    new_dist[0] += v
  else:
    letras.append(l)
    new_dist.append(v)

plt.pie(new_dist, labels=letras)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5f0b075910>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, 'outros'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'A'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'B'),
#   Text(0.8899187482945414, -0.6465637025335375, 'H')])

# %%
plt.pie(new_dist, labels=letras, autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5f0b04a390>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, 'outros'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'A'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'B'),
#   Text(0.8899187482945414, -0.6465637025335375, 'H')],
#  [Text(0.1854101859396479, 0.5706339132489631, '40.00'),
#   Text(-0.5999999999999993, -2.808802703071063e-08, '20.00'),
#   Text(-0.1854101592263464, -0.5706339219286397, '20.00'),
#   Text(0.4854102263424771, -0.3526711104728386, '20.00')])
